# %% [markdown]
# ## Логрег предсказывает каждый класс отдельно. Integer от 0 до 4

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report 
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv('/Users/annapalatkina/Desktop/big_5_PT/data/df_texts_ocean.csv')
dataset.head()
# Out:
#    user_id                                          post_text  Экстраверсия
# 0      133            Открытое образование - Главная страница          4.88  \
# 1      133     Первый день форума «Бережливое управление 2.0»          4.88
# 2      133  Есть контакт | Центры «Мои Документы» Липецкой...          4.88
# 3      133  До аэропорта «Липецк» будет ездить бесплатный ...          4.88
# 4      133                  https://vk.com/wall-171900971_843          4.88
#
#    Доброжелательность  Сознательность  Нейротизм  Открытость опыту
# 0                4.11            4.67       1.13               4.9  \
# 1                4.11            4.67       1.13               4.9
# 2                4.11            4.67       1.13               4.9
# 3                4.11            4.67       1.13               4.9
# 4                4.11            4.67       1.13               4.9
#
#    Экстраверсия_3  Доброжелательность_3  Сознательность_3  Нейротизм_3
# ...

# %% [markdown]
# # Экстраверсия

# %%
PREDICTION_COLUMN = 'Экстраверсия_3'

X = dataset.post_text_preprocessed
Y = dataset[PREDICTION_COLUMN]
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.33, random_state=42, stratify=Y)

text_transformer = TfidfVectorizer( ngram_range=(1, 2), lowercase=True, max_features=55000)
X_train_text = text_transformer.fit_transform(X_train)
X_test_text = text_transformer.transform(X_test)

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_text, y_train)
lr_pred = lr.predict(X_test_text)
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.76      0.62     36233
#            1       0.46      0.31      0.37     22137
#            2       0.53      0.35      0.42     24041
#
#     accuracy                           0.52     82411
#    macro avg       0.51      0.47      0.47     82411
# weighted avg       0.51      0.52      0.50     82411

# %%
import eli5
eli5.show_weights(estimator=lr,
                  feature_names= list(text_transformer.get_feature_names_out()),
                  top=(50, 5))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=0
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=2
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
# ...

# %% [markdown]
# # Доброжелательность

# %%
PREDICTION_COLUMN = 'Доброжелательность_3'

X = dataset.post_text_preprocessed
Y = dataset[PREDICTION_COLUMN]
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.33, random_state=42, stratify=Y)

text_transformer = TfidfVectorizer( ngram_range=(1, 2), lowercase=True, max_features=55000)
X_train_text = text_transformer.fit_transform(X_train)
X_test_text = text_transformer.transform(X_test)

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_text, y_train)
lr_pred = lr.predict(X_test_text)
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.40      0.46     24491
#            1       0.50      0.56      0.52     29552
#            2       0.49      0.54      0.52     28368
#
#     accuracy                           0.50     82411
#    macro avg       0.51      0.50      0.50     82411
# weighted avg       0.51      0.50      0.50     82411

# %%
import eli5
eli5.show_weights(estimator=lr,
                  feature_names= list(text_transformer.get_feature_names_out()),
                  top=(50, 5))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=0
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=2
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
# ...

# %% [markdown]
# # Сознательность

# %%
PREDICTION_COLUMN = 'Сознательность_3'

X = dataset.post_text_preprocessed
Y = dataset[PREDICTION_COLUMN]
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.33, random_state=42, stratify=Y)

text_transformer = TfidfVectorizer( ngram_range=(1, 2), lowercase=True, max_features=55000)
X_train_text = text_transformer.fit_transform(X_train)
X_test_text = text_transformer.transform(X_test)

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_text, y_train)
lr_pred = lr.predict(X_test_text)
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.51     26961
#            1       0.53      0.53      0.53     29741
#            2       0.49      0.50      0.49     25709
#
#     accuracy                           0.51     82411
#    macro avg       0.51      0.51      0.51     82411
# weighted avg       0.51      0.51      0.51     82411

# %%
import eli5
eli5.show_weights(estimator=lr,
                  feature_names= list(text_transformer.get_feature_names_out()),
                  top=(50, 5))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=0
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=2
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
# ...

# %% [markdown]
# # Нейротизм

# %%
PREDICTION_COLUMN = 'Нейротизм_3'

X = dataset.post_text_preprocessed
Y = dataset[PREDICTION_COLUMN]
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.33, random_state=42, stratify=Y)

text_transformer = TfidfVectorizer( ngram_range=(1, 2), lowercase=True, max_features=55000)
X_train_text = text_transformer.fit_transform(X_train)
X_test_text = text_transformer.transform(X_test)

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_text, y_train)
lr_pred = lr.predict(X_test_text)
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.25      0.35     17065
#            1       0.54      0.56      0.55     30786
#            2       0.54      0.69      0.61     34560
#
#     accuracy                           0.55     82411
#    macro avg       0.56      0.50      0.50     82411
# weighted avg       0.56      0.55      0.53     82411

# %%
import eli5
eli5.show_weights(estimator=lr,
                  feature_names= list(text_transformer.get_feature_names_out()),
                  top=(50, 5))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=0
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=2
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
# ...

# %% [markdown]
# # Открытость опыту

# %%
PREDICTION_COLUMN = 'Открытость опыту_3'

X = dataset.post_text_preprocessed
Y = dataset[PREDICTION_COLUMN]
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.33, random_state=42, stratify=Y)

text_transformer = TfidfVectorizer( ngram_range=(1, 2), lowercase=True, max_features=55000)
X_train_text = text_transformer.fit_transform(X_train)
X_test_text = text_transformer.transform(X_test)

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_text, y_train)
lr_pred = lr.predict(X_test_text)
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.69      0.57     31278
#            1       0.56      0.41      0.47     26805
#            2       0.54      0.42      0.47     24328
#
#     accuracy                           0.52     82411
#    macro avg       0.53      0.51      0.51     82411
# weighted avg       0.53      0.52      0.51     82411

# %%
import eli5
eli5.show_weights(estimator=lr,
                  feature_names= list(text_transformer.get_feature_names_out()),
                  top=(50, 5))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=0
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=2
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
# ...
